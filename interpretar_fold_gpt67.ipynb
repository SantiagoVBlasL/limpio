# %%
# %%bash
# # Bucle para los folds 2 a 5 (Fold 1 ya lo hiciste)
# for fold in {1..5}; do
#   echo "--- Procesando Fold $fold ---"
#
#   # 1. Calcular SHAP
#   python interpretar_fold_gpt.py shap \
#     --run_dir ./resultados67 --fold $fold --clf gb \
#     --global_tensor_path /home/diego/Escritorio/limpio/AAL3_dynamicROIs_fmri_tensor_NeuroEnhanced_v6.5.17_AAL3_131ROIs_OMST_GCE_Signed_GrangerLag1_ChNorm_ROIreorderedYeo17_ParallelTuned/GLOBAL_TENSOR_from_AAL3_dynamicROIs_fmri_tensor_NeuroEnhanced_v6.5.17_AAL3_131ROIs_OMST_GCE_Signed_GrangerLag1_ChNorm_ROIreorderedYeo17_ParallelTuned.npz \
#     --metadata_path /home/diego/Escritorio/limpio/SubjectsData_AAL3_procesado2.csv \
#     --channels_to_use 1 2 4 5 \
#     --latent_dim 48 \
#     --latent_features_type mu \
#     --metadata_features Age Sex Manufacturer \
#     --num_conv_layers_encoder 4 \
#     --decoder_type convtranspose \
#     --dropout_rate_vae 0.25 \
#     --use_layernorm_vae_fc \
#     --intermediate_fc_dim_vae half \
#     --vae_final_activation linear \
#     --gn_num_groups 16
#
#   # 2. Generar Saliencia
#   python interpretar_fold_gpt.py saliency \
#     --run_dir ./resultados67 --fold $fold --clf gb \
#     --global_tensor_path /home/diego/Escritorio/limpio/AAL3_dynamicROIs_fmri_tensor_NeuroEnhanced_v6.5.17_AAL3_131ROIs_OMST_GCE_Signed_GrangerLag1_ChNorm_ROIreorderedYeo17_ParallelTuned/GLOBAL_TENSOR_from_AAL3_dynamicROIs_fmri_tensor_NeuroEnhanced_v6.5.17_AAL3_131ROIs_OMST_GCE_Signed_GrangerLag1_ChNorm_ROIreorderedYeo17_ParallelTuned.npz \
#     --metadata_path /home/diego/Escritorio/limpio/SubjectsData_AAL3_procesado2.csv \
#     --roi_annotation_path /home/diego/Escritorio/limpio/roi_info_master.csv \
#     --roi_order_path /home/diego/Escritorio/limpio/roi_order_131.npy \
#     --channels_to_use 1 2 4 5 \
#     --latent_dim 48 \
#     --top_k 50 \
#     --shap_weight_mode ad_vs_cn_diff \
#     --decoder_type convtranspose \
#     --dropout_rate_vae 0.25 \
#     --use_layernorm_vae_fc \
#     --intermediate_fc_dim_vae half \
#     --vae_final_activation linear \
#     --gn_num_groups 16 \
#     --num_conv_layers_encoder 4
#
# done
#
# echo "✅ ¡Análisis de interpretabilidad para todos los folds completado!"
# Out:
# --- Procesando Fold 1 ---
# [INFO] [SHAP] fold=1 clf=gb
# [INFO] [SHAP] Cargando datos de background CRUDOS desde: shap_background_raw_gb.joblib
# [INFO] [SHAP] X_raw shape=(37, 51) (latentes + 3 metadatos)
# [INFO] [SHAP] Background DataFrame detectado pero columnas no coinciden; transformando…
# [INFO] [SHAP] Pack guardado: resultados67/fold_1/interpretability_shap/shap_pack_gb.joblib
# [INFO] [SALIENCY] fold=1 clf=gb  (pack cargado: shap_pack_gb.joblib)
# [INFO] Usando ROI order de resultados67/roi_order_131.joblib.
# [INFO] Cargado fichero de anotaciones: /home/diego/Escritorio/limpio/roi_info_master.csv
# [INFO] [SALIENCY] 48 latentes ponderadas. Ejemplo:
#  latent_idx    weight  importance           feature
#          28  0.184933    0.000214 latent__latent_28
#           8 -0.135120   -0.000157  latent__latent_8
#          46  0.113080    0.000131 latent__latent_46
#           5  0.063333    0.000073  latent__latent_5
#          33  0.062660    0.000073 latent__latent_33
# [INFO] [SALIENCY] Sujetos AD=19  CN=18
# [INFO] [SALIENCY] Ranking de conexiones ANOTADO guardado: resultados67/fold_1/interpretability_gb/ranking_conexiones_ANOTADO_top50.csv
# [INFO] Top 20 conexiones anotadas:
#       Rank src_AAL3_Name dst_AAL3_Name  Saliency_Score          src_Refined_Network          dst_Refined_Network
# 2786     1           GRR           NCR        0.000169                 Limbic_B_OFC           Brainstem_Midbrain
# 5666     2           O3R         FUSIR        0.000137            Visual_Peripheral            Visual_Peripheral
# 2788     3           GRR           NLR        0.000135                 Limbic_B_OFC  Salience_VentralAttention_A
# 2464     4          FMOL           NLR        0.000124     DefaultMode_DorsalMedial  Salience_VentralAttention_A
# 7912     5         CER3R       ACCsubL       -0.000122             DefaultMode_Core     DefaultMode_DorsalMedial
# 6413     6          GSMR        VER4_5       -0.000120  Salience_VentralAttention_A               Visual_Central
# 5541     7           O2R          T1AR       -0.000113            Visual_Peripheral            Limbic_A_TempPole
# 5591     8           O3L         FUSIR        0.000112            Visual_Peripheral            Visual_Peripheral
# 5668     9           O3R           PAR        0.000111            Visual_Peripheral                Somatomotor_A
# 6014    10           PAR          tVLL       -0.000109                Somatomotor_A       Background/NonCortical
# 6422    11          GSMR         tVPLR       -0.000108  Salience_VentralAttention_A       Background/NonCortical
# 8242    12        CER10R          VER7        0.000105                   Cerebellum       Background/NonCortical
# 7190    13       HESCHLR           T1R        0.000103                Somatomotor_B             DefaultMode_Temp
# 6423    14          GSMR         tMDmL       -0.000102  Salience_VentralAttention_A       Background/NonCortical
# 3622    15       OFCLATR           T3R        0.000101    DefaultMode_VentralMedial            Limbic_A_TempPole
# 2787    16           GRR           NLL        0.000100                 Limbic_B_OFC       Background/NonCortical
# 5667    17           O3R           PAL        0.000098            Visual_Peripheral                Somatomotor_A
# 7549    18          T2AL          VER7       -0.000095            Limbic_A_TempPole       Background/NonCortical
# 1689    19           ORR      CERCRU1R        0.000093                Somatomotor_B            Visual_Peripheral
# 7742    20      CERCRU1R         CER6R       -0.000093            Visual_Peripheral            Visual_Peripheral
# [INFO] [SALIENCY] Completo. Resultados en resultados67/fold_1/interpretability_gb
# --- Procesando Fold 2 ---
# [INFO] [SHAP] fold=2 clf=gb
# [INFO] [SHAP] Cargando datos de background CRUDOS desde: shap_background_raw_gb.joblib
# [INFO] [SHAP] X_raw shape=(37, 51) (latentes + 3 metadatos)
# [INFO] [SHAP] Background DataFrame detectado pero columnas no coinciden; transformando…
# [INFO] [SHAP] Pack guardado: resultados67/fold_2/interpretability_shap/shap_pack_gb.joblib
# [INFO] [SALIENCY] fold=2 clf=gb  (pack cargado: shap_pack_gb.joblib)
# [INFO] Usando ROI order de resultados67/roi_order_131.joblib.
# [INFO] Cargado fichero de anotaciones: /home/diego/Escritorio/limpio/roi_info_master.csv
# [INFO] [SALIENCY] 48 latentes ponderadas. Ejemplo:
#  latent_idx    weight  importance           feature
#          37  0.578543    0.209530 latent__latent_37
#          34  0.080638    0.029205 latent__latent_34
#          38 -0.034804   -0.012605 latent__latent_38
#           4  0.033227    0.012034  latent__latent_4
#          24  0.026640    0.009648 latent__latent_24
# [INFO] [SALIENCY] Sujetos AD=19  CN=18
# [INFO] [SALIENCY] Ranking de conexiones ANOTADO guardado: resultados67/fold_2/interpretability_gb/ranking_conexiones_ANOTADO_top50.csv
# [INFO] Top 20 conexiones anotadas:
#       Rank src_AAL3_Name dst_AAL3_Name  Saliency_Score          src_Refined_Network          dst_Refined_Network
# 2358     1           FMR       HESCHLR        0.000195     DefaultMode_DorsalMedial                Somatomotor_B
# 7442     2           T2L      CERCRU2R       -0.000163    DefaultMode_VentralMedial                   Cerebellum
# 2365     3           FMR          T2AL        0.000162     DefaultMode_DorsalMedial            Limbic_A_TempPole
# 2247     4           FML       HESCHLR        0.000162    DefaultMode_VentralMedial                Somatomotor_B
# 4752     5        AMYGDR        VER4_5       -0.000156            Limbic_A_TempPole               Visual_Central
# 7500     6           T2R        CER10L        0.000155            DorsalAttention_A                   Cerebellum
# 7046     7         PALLL      CERCRU2R       -0.000153                Basal_Ganglia                   Cerebellum
# 5090     8            QR        VER4_5       -0.000152               Visual_Central               Visual_Central
# 2322     9           FMR        AMYGDR        0.000148     DefaultMode_DorsalMedial            Limbic_A_TempPole
# 1623    10           ORR       OFCMEDR        0.000142                Somatomotor_B                 Limbic_B_OFC
# 8088    11        CER7BR          VER6        0.000140                   Cerebellum            Visual_Peripheral
# 1323    12        F3O_2L       HESCHLR        0.000139    DefaultMode_VentralMedial                Somatomotor_B
# 5091    13            QR          VER6       -0.000139               Visual_Central            Visual_Peripheral
# 6994    14           NLR         CER3R       -0.000137  Salience_VentralAttention_A             DefaultMode_Core
# 2764    15           GRR           O1R       -0.000136                 Limbic_B_OFC            Visual_Peripheral
# 7387    16          T1AR           T2L       -0.000135            Limbic_A_TempPole    DefaultMode_VentralMedial
# 6586    17           PQL      CERCRU2R       -0.000135     DefaultMode_DorsalMedial                   Cerebellum
# 6697    18          LPCL          T1AR        0.000135                Somatomotor_A            Limbic_A_TempPole
# 6568    19           PQL           NLR        0.000135     DefaultMode_DorsalMedial  Salience_VentralAttention_A
# 4275    20        HIPPOL         PALLR        0.000134             DefaultMode_Core                Basal_Ganglia
# [INFO] [SALIENCY] Completo. Resultados en resultados67/fold_2/interpretability_gb
# --- Procesando Fold 3 ---
# [INFO] [SHAP] fold=3 clf=gb
# [INFO] [SHAP] Cargando datos de background CRUDOS desde: shap_background_raw_gb.joblib
# [INFO] [SHAP] X_raw shape=(37, 51) (latentes + 3 metadatos)
# [INFO] [SHAP] Background DataFrame detectado pero columnas no coinciden; transformando…
# [INFO] [SHAP] Pack guardado: resultados67/fold_3/interpretability_shap/shap_pack_gb.joblib
# [INFO] [SALIENCY] fold=3 clf=gb  (pack cargado: shap_pack_gb.joblib)
# [INFO] Usando ROI order de resultados67/roi_order_131.joblib.
# [INFO] Cargado fichero de anotaciones: /home/diego/Escritorio/limpio/roi_info_master.csv
# [INFO] [SALIENCY] 48 latentes ponderadas. Ejemplo:
#  latent_idx   weight  importance           feature
#          28 0.171470    0.000048 latent__latent_28
#           5 0.168046    0.000047  latent__latent_5
#          38 0.137003    0.000038 latent__latent_38
#          24 0.070234    0.000019 latent__latent_24
#           4 0.046859    0.000013  latent__latent_4
# [INFO] [SALIENCY] Sujetos AD=19  CN=18
# [INFO] [SALIENCY] Ranking de conexiones ANOTADO guardado: resultados67/fold_3/interpretability_gb/ranking_conexiones_ANOTADO_top50.csv
# [INFO] Top 20 conexiones anotadas:
#       Rank src_AAL3_Name dst_AAL3_Name  Saliency_Score          src_Refined_Network     dst_Refined_Network
# 7576     1          T2AR         CER3R       -0.000115            Limbic_A_TempPole        DefaultMode_Core
# 7018     2           NLR         tMDmL       -0.000106  Salience_VentralAttention_A  Background/NonCortical
# 4036     3         CINMR         tVPLL       -0.000106  Salience_VentralAttention_A  Background/NonCortical
# 8250     4        CER10R         tMDmL       -0.000099                   Cerebellum  Background/NonCortical
# 8332     5          VER7         tMDmL       -0.000097       Background/NonCortical  Background/NonCortical
# 5720     6           O3R          VER7        0.000095            Visual_Peripheral  Background/NonCortical
# 8246     7        CER10R          tVLL       -0.000092                   Cerebellum  Background/NonCortical
# 5565     8           O2R        CER10R       -0.000090            Visual_Peripheral              Cerebellum
# 7738     9      CERCRU1R         CER3R       -0.000089            Visual_Peripheral        DefaultMode_Core
# 6784    10          LPCR          VER7       -0.000085                Somatomotor_A  Background/NonCortical
# 2832    11           GRR         tMDmL       -0.000082                 Limbic_B_OFC  Background/NonCortical
# 6760    12          LPCR          T2AR        0.000080                Somatomotor_A       Limbic_A_TempPole
# 1900    13          SMAR          LPCR       -0.000080                Somatomotor_A           Somatomotor_A
# 5712    14           O3R         CER8R       -0.000080            Visual_Peripheral              Cerebellum
# 3574    15       OFCLATR   PARA_HIPPOR        0.000079    DefaultMode_VentralMedial       Limbic_A_TempPole
# 2740    16           GRR       OFCANTR        0.000079                 Limbic_B_OFC               Control_B
# 2334    17           FMR           O3R       -0.000078     DefaultMode_DorsalMedial       Visual_Peripheral
# 1808    18          SMAL         CER3L       -0.000076  Salience_VentralAttention_A              Cerebellum
# 4392    19        HIPPOR         CER8R       -0.000076            Limbic_A_TempPole              Cerebellum
# 8325    20          VER7          VER8       -0.000074       Background/NonCortical  Background/NonCortical
# [INFO] [SALIENCY] Completo. Resultados en resultados67/fold_3/interpretability_gb
# --- Procesando Fold 4 ---
# [INFO] [SHAP] fold=4 clf=gb
# [INFO] [SHAP] Cargando datos de background CRUDOS desde: shap_background_raw_gb.joblib
# [INFO] [SHAP] X_raw shape=(37, 51) (latentes + 3 metadatos)
# [INFO] [SHAP] Background DataFrame detectado pero columnas no coinciden; transformando…
# [INFO] [SHAP] Pack guardado: resultados67/fold_4/interpretability_shap/shap_pack_gb.joblib
# [INFO] [SALIENCY] fold=4 clf=gb  (pack cargado: shap_pack_gb.joblib)
# [INFO] Usando ROI order de resultados67/roi_order_131.joblib.
# [INFO] Cargado fichero de anotaciones: /home/diego/Escritorio/limpio/roi_info_master.csv
# [INFO] [SALIENCY] 48 latentes ponderadas. Ejemplo:
#  latent_idx   weight  importance           feature
#          45 0.542941    0.000070 latent__latent_45
#          26 0.106223    0.000014 latent__latent_26
#          32 0.057619    0.000007 latent__latent_32
#           4 0.055620    0.000007  latent__latent_4
#          14 0.048716    0.000006 latent__latent_14
# [INFO] [SALIENCY] Sujetos AD=19  CN=18
# [INFO] [SALIENCY] Ranking de conexiones ANOTADO guardado: resultados67/fold_4/interpretability_gb/ranking_conexiones_ANOTADO_top50.csv
# [INFO] Top 20 conexiones anotadas:
#       Rank src_AAL3_Name dst_AAL3_Name  Saliency_Score          src_Refined_Network     dst_Refined_Network
# 6252     1           P2R       HESCHLR        0.000347                    Control_B           Somatomotor_B
# 6250     2           P2R         PALLR        0.000249                    Control_B           Basal_Ganglia
# 6373     3          GSMR           PQR        0.000225  Salience_VentralAttention_A               Control_C
# 6184     4           P2L       HESCHLL        0.000220                    Control_A           Somatomotor_B
# 5979     5           PAR           T1L        0.000209                Somatomotor_A           Somatomotor_B
# 6508     6           GAR         PALLR        0.000207     DefaultMode_DorsalMedial           Basal_Ganglia
# 6516     7           GAR           T2R        0.000203     DefaultMode_DorsalMedial       DorsalAttention_A
# 3082     8       OFCANTL           O3L        0.000200                 Limbic_B_OFC       Visual_Peripheral
# 6415     9          GSMR          VER7        0.000200  Salience_VentralAttention_A  Background/NonCortical
# 2111    10          COBR           O3R        0.000197                 Limbic_B_OFC       Visual_Peripheral
# 2537    11          FMOR        HIPPOR       -0.000195     DefaultMode_DorsalMedial       Limbic_A_TempPole
# 8289    12        VER4_5          tVLL       -0.000193               Visual_Central  Background/NonCortical
# 6625    13           PQR          LPCR        0.000193                    Control_C           Somatomotor_A
# 5685    14           O3R         PALLL        0.000192            Visual_Peripheral           Basal_Ganglia
# 6980    15           NLR           T1R        0.000185  Salience_VentralAttention_A        DefaultMode_Temp
# 6893    16           NCR         CER9R        0.000183           Brainstem_Midbrain              Cerebellum
# 1884    17          SMAR           O3R        0.000181                Somatomotor_A       Visual_Peripheral
# 1671    18           ORR           NCR        0.000181                Somatomotor_B      Brainstem_Midbrain
# 5612    19           O3L       HESCHLL        0.000181            Visual_Peripheral           Somatomotor_B
# 1922    20          SMAR      CERCRU2R        0.000179                Somatomotor_A              Cerebellum
# [INFO] [SALIENCY] Completo. Resultados en resultados67/fold_4/interpretability_gb
# --- Procesando Fold 5 ---
# [INFO] [SHAP] fold=5 clf=gb
# [INFO] [SHAP] Cargando datos de background CRUDOS desde: shap_background_raw_gb.joblib
# [INFO] [SHAP] X_raw shape=(36, 51) (latentes + 3 metadatos)
# [INFO] [SHAP] Background DataFrame detectado pero columnas no coinciden; transformando…
# [INFO] [SHAP] Pack guardado: resultados67/fold_5/interpretability_shap/shap_pack_gb.joblib
# [INFO] [SALIENCY] fold=5 clf=gb  (pack cargado: shap_pack_gb.joblib)
# [INFO] Usando ROI order de resultados67/roi_order_131.joblib.
# [INFO] Cargado fichero de anotaciones: /home/diego/Escritorio/limpio/roi_info_master.csv
# [INFO] [SALIENCY] 48 latentes ponderadas. Ejemplo:
#  latent_idx    weight  importance           feature
#          14  0.187563    0.001028 latent__latent_14
#          43 -0.136566   -0.000748 latent__latent_43
#          38  0.110211    0.000604 latent__latent_38
#          17  0.061534    0.000337 latent__latent_17
#           2  0.050350    0.000276  latent__latent_2
# [INFO] [SALIENCY] Sujetos AD=19  CN=17
# [INFO] [SALIENCY] Ranking de conexiones ANOTADO guardado: resultados67/fold_5/interpretability_gb/ranking_conexiones_ANOTADO_top50.csv
# [INFO] Top 20 conexiones anotadas:
#       Rank src_AAL3_Name dst_AAL3_Name  Saliency_Score        src_Refined_Network     dst_Refined_Network
# 2173     1          COBR         tVPLL       -0.000123               Limbic_B_OFC  Background/NonCortical
# 4360     2        HIPPOR          LPCR       -0.000117          Limbic_A_TempPole           Somatomotor_A
# 1179     3          F3TR           O3R       -0.000115                  Control_A       Visual_Peripheral
# 5829     4         FUSIR           NCR       -0.000111          Visual_Peripheral      Brainstem_Midbrain
# 6270     5           P2R       CER4_5R       -0.000110                  Control_B          Visual_Central
# 2115     6          COBR           PAR       -0.000102               Limbic_B_OFC           Somatomotor_A
# 2223     7           FML           O3R       -0.000101  DefaultMode_VentralMedial       Visual_Peripheral
# 3606     8       OFCLATR           NCR       -0.000099  DefaultMode_VentralMedial      Brainstem_Midbrain
# 5819     9         FUSIR           P2R       -0.000098          Visual_Peripheral               Control_B
# 2114    10          COBR           PAL       -0.000096               Limbic_B_OFC           Somatomotor_A
# 5515    11           O2R         FUSIR       -0.000093          Visual_Peripheral       Visual_Peripheral
# 2657    12           GRL           O1R       -0.000090               Limbic_B_OFC       Visual_Peripheral
# 2446    13          FMOL         FUSIR       -0.000090   DefaultMode_DorsalMedial       Visual_Peripheral
# 2555    14          FMOR         FUSIR       -0.000088   DefaultMode_DorsalMedial       Visual_Peripheral
# 1884    15          SMAR           O3R       -0.000087              Somatomotor_A       Visual_Peripheral
# 2645    16           GRL        HIPPOR       -0.000087               Limbic_B_OFC       Limbic_A_TempPole
# 5231    17         LINGR          T2AR       -0.000087             Visual_Central       Limbic_A_TempPole
# 2553    18          FMOR           O3R       -0.000086   DefaultMode_DorsalMedial       Visual_Peripheral
# 2000    19          COBL         FUSIR       -0.000085               Limbic_B_OFC       Visual_Peripheral
# 3407    20      OFCPOSTR           NCR       -0.000085               Limbic_B_OFC      Brainstem_Midbrain
# [INFO] [SALIENCY] Completo. Resultados en resultados67/fold_5/interpretability_gb
# ✅ ¡Análisis de interpretabilidad para todos los folds completado!

# %%
# CELDA 1 ─── imports y paths
import json, glob, numpy as np, scipy.stats as st
from skimage.metrics import adapted_rand_error as dice   # 1–ARE ≈ Dice
RUN_DIR = "./resultados33"
SAL_MAPS = sorted(glob.glob(f"{RUN_DIR}/fold_*/interpretability_xgb/saliency_map_diff_top50.npy"))
assert len(SAL_MAPS) == 5, f"Faltan mapas: {SAL_MAPS}"
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[2], line 6
#       4 RUN_DIR = "./resultados33"
#       5 SAL_MAPS = sorted(glob.glob(f"{RUN_DIR}/fold_*/interpretability_xgb/saliency_map_diff_top50.npy"))
# ----> 6 assert len(SAL_MAPS) == 5, f"Faltan mapas: {SAL_MAPS}"
#
# AssertionError: Faltan mapas: []

# %%
# CELDA 2 ─── grand average + métricas
diff_maps = [np.load(p) for p in SAL_MAPS]                 # list len=5, shape (C,R,R)
diff_avg  = np.mean(diff_maps, axis=0).astype(np.float32)  # (C,R,R)
np.save(f"{RUN_DIR}/grand_average_saliency.npy", diff_avg)

# vector upper-triangular por fold (promedio sobre canales)
vecs = [m.mean(axis=0)[np.triu_indices(m.shape[-1],1)] for m in diff_maps]
# Pearson ρ y Dice inter-fold
n     = len(vecs)
rhos  = [st.pearsonr(vecs[i], vecs[j])[0]        for i in range(n) for j in range(i+1,n)]
dices = [1-dice(vecs[i]>0, vecs[j]>0)[0]         for i in range(n) for j in range(i+1,n)]

stats = {
    "rho_mean":        float(np.mean(rhos)),   "rho_std":   float(np.std(rhos)),
    "dice_mean":       float(np.mean(dices)),  "dice_std":  float(np.std(dices)),
    "sign_agreement":  float(np.mean([(v1>0)==(v2>0) for i,v1 in enumerate(vecs) for v2 in vecs[i+1:]]))
}
json.dump(stats, open(f"{RUN_DIR}/saliency_stats.json","w"), indent=2)
stats
# Out:
# {'rho_mean': 0.01309380866587162,
#  'rho_std': 0.019735191017389297,
#  'dice_mean': 0.6778316811769827,
#  'dice_std': 0.017419429334272082,
#  'sign_agreement': 0.5057193188490898}

# %%
# CELDA 3 ─── heat-map del patrón medio (opcional figura para el paper)
import seaborn as sns, matplotlib.pyplot as plt
roi_names = np.load("/home/diego/Escritorio/limpio/roi_order_131.npy")
plt.figure(figsize=(10,8))
sns.heatmap(diff_avg.mean(axis=0), cmap="coolwarm", center=0,
            xticklabels=roi_names, yticklabels=roi_names,
            cbar_kws=dict(label="Saliencia AD > CN"))
plt.title("Grand-average saliency (XGB, top-50 latentes, n=5 folds)")
plt.tight_layout(); plt.savefig(f"{RUN_DIR}/grand_average_heatmap.png", dpi=300)
plt.show()

# %%
import glob, pandas as pd, numpy as np, scipy.stats as st
RUN_DIR = "./resultados33"                       # <- ajusta si cambias de carpeta
csv_paths = sorted(
    glob.glob(f"{RUN_DIR}/fold_*/interpretability_xgb/"
              "ranking_conexiones_ANOTADO_top50.csv")
)

dfs = []
for fold, path in enumerate(csv_paths, 1):
    df = (pd.read_csv(path)
            .assign(fold=fold)
            .rename(columns={'Saliency_Score': 'score'}))
    
    # ⚠️ Nos aseguramos de que el identificador del edge sea INDEPENDIENTE del orden
    df['edge_id'] = (df[['src_AAL3_Name', 'dst_AAL3_Name']]
                     .apply(lambda r: ' — '.join(sorted(r)), axis=1))
    dfs.append(df[['edge_id', 'score', 'fold']])

all_edges = pd.concat(dfs, ignore_index=True)

# %%
def ci95(series):
    """IC95 % bilateral para n<=30 usando t de Student."""
    n = series.size
    m = series.mean()
    s = series.std(ddof=1)
    t_crit = st.t.ppf(0.975, df=n-1)
    half_width = t_crit * s / np.sqrt(n)
    return pd.Series({'mean': m, 'ci_low': m-half_width, 'ci_high': m+half_width})

edge_stats = (all_edges
              .groupby('edge_id')['score']
              .apply(ci95)        # devuelve Serie con índice 'mean', 'ci_low', …
              .unstack()          # pasa ese índice a columnas
              .reset_index())     # deja 'edge_id' como columna normal


# ordenamos por |media| y nos quedamos con los 10 primeros
top10 = (edge_stats
         .assign(abs_mean=lambda d: d['mean'].abs())
         .sort_values('abs_mean', ascending=False)
         .head(10)
         .drop(columns='abs_mean'))

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))

y = np.arange(len(top10))[::-1]            # barras horizontales (de arriba abajo)
plt.barh(y,  top10['mean'], xerr=[top10['mean']-top10['ci_low'],
                                  top10['ci_high']-top10['mean']],
         alpha=0.8, capsize=4)

plt.yticks(y, top10['edge_id'])
plt.xlabel('Saliencia diferencial (AD > CN)')
plt.title('Top-10 conexiones | media ± IC 95 % (5 folds)')
plt.tight_layout()
plt.savefig(f"{RUN_DIR}/fig_top10_edges_ic95.png", dpi=300)
plt.show()

# %%
top10.to_csv(f"{RUN_DIR}/top10_edges_ic95.csv", index=False)

# %%
import numpy as np
sal = np.load("/home/diego/Escritorio/limpio/resultados33/grand_average_saliency.npy")        # shape (C, R, R)
print("Shape de la saliencia:", sal.shape)
w_r = sal.mean(0).sum(axis=0) + sal.mean(0).sum(axis=1)  # col + row
w_r = np.abs(w_r); w_r /= w_r.sum()                # normaliza
np.save("roi_weights.npy", w_r)
print("Pesos de las ROIs guardados en 'roi_weights.npy'.")
# Out:
# Shape de la saliencia: (2, 131, 131)
# Pesos de las ROIs guardados en 'roi_weights.npy'.

# %%
import numpy as np
import nibabel as nib
from nilearn import plotting

# --- 1. Carga el atlas volumétrico ya reordenado ---
atlas_nii = nib.load("/home/diego/Escritorio/limpio/AAL3v1.nii.gz")        # mismo que usaste para parcellar
atlas_data = atlas_nii.get_fdata().astype(int)        # (x,y,z)

# --- 2. Vector de pesos por ROI ---
w_r = np.load("roi_weights.npy")                      # shape = (131,)

# --- 3. Construye un volumen con los pesos ---
roi_weight_vol = np.zeros_like(atlas_data, dtype=float)
for roi_idx, weight in enumerate(w_r, start=1):       # AAL etiquetas empiezan en 1
    roi_weight_vol[atlas_data == roi_idx] = weight

roi_weight_img = nib.Nifti1Image(roi_weight_vol, atlas_nii.affine, atlas_nii.header)

# --- 4. Dibuja ---
plotting.plot_stat_map(
    roi_weight_img,
    threshold=0.005,          # ajusta si quieres dejar fuera valores pequeños
    display_mode="ortho",     # 'x', 'y', 'z', etc.
    cmap="hot_r",
    colorbar=True,
    title="ROI-level saliency mass"
)

# %%
import numpy as np
import nibabel as nib
from nilearn import surface, plotting, datasets

# ---- 1. Volumen con pesos (como antes) ----
#roi_weight_img = nib.load("roi_weight_img.nii.gz")    # o crea con el bucle anterior

# ---- 2. Mallas fsaverage ----
fsavg = datasets.fetch_surf_fsaverage('fsaverage5')
# fsavg.infl_left  / fsavg.infl_right  → mallas infladas

texture_lh = surface.vol_to_surf(roi_weight_img, fsavg.pial_left)
texture_rh = surface.vol_to_surf(roi_weight_img, fsavg.pial_right)

# ---- 3. Pinta cada hemisferio ----
plotting.plot_surf_stat_map(
    surf_mesh=fsavg.infl_left,
    stat_map=texture_lh,
    hemi='left',
    colorbar=True, cmap='hot_r',
    title='Saliency mass – LH'
)

plotting.plot_surf_stat_map(
    surf_mesh=fsavg.infl_right,
    stat_map=texture_rh,
    hemi='right',
    colorbar=True, cmap='hot_r',
    title='Saliency mass – RH'
)
